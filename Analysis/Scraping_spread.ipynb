# %% [markdown]
# <a href="https://colab.research.google.com/github/sherlockian4869/python/blob/main/Analysis/Scraping_spread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from oauth2client.client import GoogleCredentials
import gspread

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
ss_name = 'サンプルシート'
workbook = gc.open(ss_name)
worksheet = workbook.worksheet('シート2')

# %%
values = worksheet.get_all_values()
print(values)
# Out:
# [['大阪'], ['ビル'], ['火災'], ['精神'], ['鑑定'], ['被害'], ['し'], ['公平'], ['ない'], ['悲痛'], ['声'], ['弁護'], ['法律'], ['万能'], ['痛感'], ['さ'], ['ABEMA'], ['TIMES'], ['Yahoo'], ['ニュース'], ['容疑'], ['火'], ['つける'], ['様子'], ['防犯'], ['カメラ'], ['2021'], ['年'], ['12'], ['月'], ['19'], ['連日'], ['報道'], ['憧れ'], ['しまう'], ['人'], ['一定'], ['数'], ['いる'], ['犯罪'], ['生む'], ['状況'], ['心配'], ['本仮屋'], ['懸念'], ['国内'], ['消防'], ['緊急'], ['検査'], ['放火'], ['事件'], ['受け'], ['静岡'], ['院長'], ['８'], ['身元'], ['発表'], ['殺人'], ['日本'], ['テレビ'], ['NNN'], ['世界'], ['急'], ['拡大'], ['オランダ'], ['年末'], ['休暇'], ['前'], ['ロック'], ['ダウン'], ['新型'], ['コロナ'], ['ウイルス'], ['株'], ['警戒'], ['強まる'], ['20'], ['欧米'], ['猛威'], ['都市'], ['封鎖'], ['直撃'], ['欧州'], ['感染'], ['英'], ['首都'], ['事態'], ['宣言'], ['リスク'], ['回避'], ['円買い'], ['優勢'], ['クリスマス'], ['政府'], ['職場'], ['接種'], ['前倒し'], ['検討'], ['最大'], ['35'], ['兆'], ['円'], ['補正'], ['予算'], ['成立'], ['共同'], ['通信'], ['速報'], ['過去'], ['年度'], ['総額'], ['３５'], ['９８９５'], ['億'], ['3'], ['回'], ['厚労'], ['表明'], ['22'], ['2'], ['メド'], ['全国'], ['海外'
# ...

# %%
import itertools
value_list = sum(values, [])
print(value_list)
# Out:
# ['大阪', 'ビル', '火災', '精神', '鑑定', '被害', 'し', '公平', 'ない', '悲痛', '声', '弁護', '法律', '万能', '痛感', 'さ', 'ABEMA', 'TIMES', 'Yahoo', 'ニュース', '容疑', '火', 'つける', '様子', '防犯', 'カメラ', '2021', '年', '12', '月', '19', '連日', '報道', '憧れ', 'しまう', '人', '一定', '数', 'いる', '犯罪', '生む', '状況', '心配', '本仮屋', '懸念', '国内', '消防', '緊急', '検査', '放火', '事件', '受け', '静岡', '院長', '８', '身元', '発表', '殺人', '日本', 'テレビ', 'NNN', '世界', '急', '拡大', 'オランダ', '年末', '休暇', '前', 'ロック', 'ダウン', '新型', 'コロナ', 'ウイルス', '株', '警戒', '強まる', '20', '欧米', '猛威', '都市', '封鎖', '直撃', '欧州', '感染', '英', '首都', '事態', '宣言', 'リスク', '回避', '円買い', '優勢', 'クリスマス', '政府', '職場', '接種', '前倒し', '検討', '最大', '35', '兆', '円', '補正', '予算', '成立', '共同', '通信', '速報', '過去', '年度', '総額', '３５', '９８９５', '億', '3', '回', '厚労', '表明', '22', '2', 'メド', '全国', '海外', '徳島', '新聞', '電子', '版', 'フィリピン', '台風', '号', '北上', 'のち', '東より', '気象', '予報', '日直', '主任', '通過', '洪水', '死者', '169', '朝日', 'ANN', '大型', '100', '写真', '２２', '崩壊', '家屋', '死亡', '１００', '超える', '襲っ', '時速', '２５９', 'キロ', 'スーパー', '中央', '日報', '語', '失業', '給付', 
# ...

# %%
# !apt-get -y install fonts-ipafont-gothic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 1s (6,648 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# ...

# %%
import collections
count = collections.Counter(value_list)
print(count)
# Out:
# Counter({'ビル': 3, '火災': 3, '被害': 3, 'ない': 3, '放火': 3, '受け': 3, '年末': 3, '職場': 3, '接種': 3, '前倒し': 3, '検討': 3, '最大': 3, '円': 3, '補正': 3, '予算': 3, '成立': 3, '共同': 3, '過去': 3, '3': 3, '厚労': 3, '失業': 3, '給付': 3, '保険': 3, '0': 3, '増': 3, '先送り': 3, '巡り': 3, '自民': 3, '1': 3, '10': 3, '懸念': 2, '警戒': 2, '感染': 2, '億': 2, '全国': 2, '負担': 2, '以降': 2, 'する': 2, '規模': 2, '文通': 2, '譲歩': 2, '案': 2, '提示': 2, 'Xマス': 2, '頃': 2, '寒波': 2, '寒い': 2, '衆院': 2, '減': 2, '議長': 2, '異例': 2, '批判': 2, '建設': 2, '残土': 2, '処理': 2, '45': 2, '件': 2, '黒い': 2, '雨': 2, '救済': 2, '認定': 2, '万': 2, '診療': 2, '報酬': 2, '本体': 2, '43': 2, 'NHK': 2, '値下げ': 2, '法': 2, '提出': 2, '総務': 2, '方針': 2, '全額': 2, '現金': 2, '望む': 2, '79': 2, '次ぐ': 2, '訃報': 2, '焦る': 2, '拉致': 2, '家族': 2, 'ガソリン': 2, '使い': 2, '規制': 2, '抜け道': 2, '雑居': 2, '棟': 2, '調査': 2, '北陸': 2, '東北': 2, '雷雨': 2, '強': 2, '雪': 2, '注意': 2, '追加': 2, '早く': 2, '65': 2, '毎日': 2, '教員': 2, '復職': 2, '公明': 2, '強い': 2, '国会': 2, '大阪': 1, '精神': 1, '鑑定': 1, 'し': 1, '公平': 1, '悲痛': 1, '声': 1, '弁護': 1, 
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import random
import codecs
fpath = './fonts/IPAfont00303/ipagp.ttf'

def show_word_cloud(ws):
    ws_show = []
    for i in range(len(ws)):
        word_times = ws[i][1]
        if word_times>0:
            for j in range(word_times):
                ws_show.append(ws[i][0])
    # 綺麗に整列してると、「あああ あああ」という単語と判断されるので、シャッフル
    random.shuffle(ws_show)
    # スペース区切り
    texts = ' '.join(ws_show)
    #print(texts)
    
    # 描画
    wc = WordCloud(background_color="white", font_path=fpath, 
                   width=800, height=400, regexp=r"[\w']+").generate(texts)
    plt.figure(figsize=(15,12))
    plt.imshow(wc)
    plt.axis('off')
    plt.show()

show_word_cloud(count.most_common(25))
# show_word_cloud(count)
